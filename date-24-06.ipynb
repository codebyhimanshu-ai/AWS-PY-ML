# %% [markdown]
# <a href="https://colab.research.google.com/github/codebyhimanshu-ai/AWS-PY-ML/blob/main/date-24-06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read CSV file from GitHub
csv_url = "https://raw.githubusercontent.com/codebyhimanshu-ai/AWS-PY-ML/main/py1/student.csv"
csv_df = pd.read_csv(csv_url)
print(csv_df)

print("\n")

# Read JSON file from GitHub
json_url = "https://raw.githubusercontent.com/codebyhimanshu-ai/AWS-PY-ML/main/py1/data.json"
json_df = pd.read_json(json_url)
print(json_df)
# Out:
#        name  gender  age
# 0  Himanshu    Male   22
# 1     Rahul    Male   21
# 2     Priya  Female   20
# 3    Anjali  Female   23
# 4      Aman    Male   24
#
#
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40
